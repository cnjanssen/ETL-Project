# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
#this is the link for csv: https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j/data

# %%
csv_file = './Resources/NYC_Restaurant_Inspection_Results.csv'
Restaurant_Inspection_Results_df = pd.read_csv(csv_file)
Restaurant_Inspection_Results_df.head()
# Out:
#       CAMIS                           DBA       BORO BUILDING  \
# 0  41232877                     GEO SI GI     Queens    15228
# 1  50014465  MIYABI SUSHI & ASIAN CUISINE  Manhattan      118
# 2  50056033        LA COLOMBIANITA BAKERY     Queens    10837
# 3  41081943                        SUBWAY  Manhattan        1
# 4  41628216                   OVI'S PLACE   Brooklyn     2925
#
#                STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  NORTHERN BOULEVARD  11354.0  7188880001              Korean
# 1            W 3RD ST  10012.0  2122281688            Japanese
# 2          CORONA AVE  11368.0  7183930063              Bakery
# 3          PENN PLAZA  10119.0  2122394212          Sandwiches
# 4            AVENUE H  11210.0  7184211640            American
#
#   INSPECTION DATE                                           ACTION  ...  \
# 0      02/13/2018  Violations were cited in the following area(s).  ...
# 1      12/08/2017  Violations were cited in the following area(s).  ...
# 2      05/23/2017  Violations were cited in the following area(s).  ...
# 3      05/07/2018  Violations were cited in the following area(s).  ...
# 4      07/29/2019  Violations were cited in the following area(s).  ...
#
#   RECORD DATE                                    INSPECTION TYPE   Latitude  \
# 0  11/18/2019                   Cycle Inspection / Re-inspection  40.764889
# 1  11/18/2019                   Cycle Inspection / Re-inspection  40.730544
# 2  11/18/2019              Cycle Inspection / Initial Inspection  40.742495
# 3  11/18/2019              Cycle Inspection / Initial Inspection  40.751091
# 4  11/18/2019  Administrative Miscellaneous / Initial Inspection  40.631537
#
#    Longitude Community Board Council District Census Tract        BIN  \
# 0 -73.812143           407.0             20.0     115500.0  4119195.0
# 1 -74.000386           102.0              1.0       6500.0  1008745.0
# 2 -73.854097           404.0             21.0      42700.0  4443008.0
# 3 -73.992926           105.0              3.0      10100.0  1014387.0
# 4 -73.947962           314.0             45.0      77400.0  3205898.0
#
#             BBL   NTA
# 0  4.052660e+09  QN51
# 1  1.005430e+09  MN23
# 2  4.020090e+09  QN25
# 3  1.007830e+09  MN17
# 4  3.075570e+09  BK42
#
# [5 rows x 26 columns]

# %%
Clean_Restaurant_Inspection_Results_df = Restaurant_Inspection_Results_df[['DBA','BORO','BUILDING','STREET',
                                      'ZIPCODE','PHONE','CUISINE DESCRIPTION',
                                      'INSPECTION DATE','ACTION','RECORD DATE',
                                      'INSPECTION TYPE','VIOLATION CODE','VIOLATION DESCRIPTION']].copy()
Clean_Restaurant_Inspection_Results_df .head()
# Out:
#                             DBA       BORO BUILDING              STREET  \
# 0                     GEO SI GI     Queens    15228  NORTHERN BOULEVARD
# 1  MIYABI SUSHI & ASIAN CUISINE  Manhattan      118            W 3RD ST
# 2        LA COLOMBIANITA BAKERY     Queens    10837          CORONA AVE
# 3                        SUBWAY  Manhattan        1          PENN PLAZA
# 4                   OVI'S PLACE   Brooklyn     2925            AVENUE H
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11354.0  7188880001              Korean      02/13/2018
# 1  10012.0  2122281688            Japanese      12/08/2017
# 2  11368.0  7183930063              Bakery      05/23/2017
# 3  10119.0  2122394212          Sandwiches      05/07/2018
# 4  11210.0  7184211640            American      07/29/2019
#
#                                             ACTION RECORD DATE  \
# 0  Violations were cited in the following area(s).  11/18/2019
# 1  Violations were cited in the following area(s).  11/18/2019
# 2  Violations were cited in the following area(s).  11/18/2019
# 3  Violations were cited in the following area(s).  11/18/2019
# 4  Violations were cited in the following area(s).  11/18/2019
#
#                                      INSPECTION TYPE VIOLATION CODE  \
# 0                   Cycle Inspection / Re-inspection            02G
# 1                   Cycle Inspection / Re-inspection            08A
# 2              Cycle Inspection / Initial Inspection            02B
# 3              Cycle Inspection / Initial Inspection            06A
# 4  Administrative Miscellaneous / Initial Inspection            22G
#
#                                VIOLATION DESCRIPTION
# 0  Cold food item held above 41º F (smoked fish a...
# 1  Facility not vermin proof. Harborage or condit...
# 2         Hot food item not held at or above 140º F.
# 3  Personal cleanliness inadequate. Outer garment...
# 4                                                NaN

# %%
Clean_Restaurant_Inspection_Results_df .dropna(0)
# Out:
#                                  DBA       BORO BUILDING              STREET  \
# 0                          GEO SI GI     Queens    15228  NORTHERN BOULEVARD
# 1       MIYABI SUSHI & ASIAN CUISINE  Manhattan      118            W 3RD ST
# 2             LA COLOMBIANITA BAKERY     Queens    10837          CORONA AVE
# 3                             SUBWAY  Manhattan        1          PENN PLAZA
# 5                       CHICK-N-RICE     Queens    27119          UNION TPKE
# ...                              ...        ...      ...                 ...
# 397075        COMPADRES MEXICAN FOOD     Queens     9221         LIBERTY AVE
# 397076                    GRIMALDI'S     Queens    24202           61 AVENUE
# 397077                   TANOSHI TEI  Manhattan     1374            YORK AVE
# 397078                COCO MOKA CAFE  Manhattan        2          PENN PLAZA
# 397079             The Crossbar Cafe     Queens     3423             38TH ST
#
#         ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0       11354.0  7188880001              Korean      02/13/2018
# 1       10012.0  2122281688            Japanese      12/08/2017
# 2       11368.0  7183930063              Bakery      05/23/2017
# 3       10119.0  2122394212          Sandwiches      05/07/2018
# 5       11040.0  9173878585      Middle Eastern      09/17/2019
# ...         ...         ...                 ...             ...
# 397075  11417.0  7183232660             Mexican      02/28/2019
# 397076  11362.0  7188192133               Pizza      04/17/2019
# 397077  10021.0  6464762893            Japanese      05/28/2019
# 397078  10121.0  2127142777            American      05/13/2016
# 397079  11101.0  6468637076     Café/Coffee/Tea      09/20/2018
#
#                                                  ACTION RECORD DATE  \
# 0       Violations were cited in the following area(s).  11/18/2019
# 1       Violations were cited in the following area(s).  11/18/2019
# 2       Violations were cited in the following area(s).  11/18/2019
# 3       Violations were cited in the following area(s).  11/18/2019
# 5       Violations were cited in the following area(s).  11/18/2019
# ...                                                 ...         ...
# 397075  Violations were cited in the following area(s).  11/18/2019
# 397076  Violations were cited in the following area(s).  11/18/2019
# 397077  Violations were cited in the following area(s).  11/18/2019
# 397078  Violations were cited in the following area(s).  11/18/2019
# 397079  Violations were cited in the following area(s).  11/18/2019
#
#                                       INSPECTION TYPE VIOLATION CODE  \
# 0                    Cycle Inspection / Re-inspection            02G
# 1                    Cycle Inspection / Re-inspection            08A
# 2               Cycle Inspection / Initial Inspection            02B
# 3               Cycle Inspection / Initial Inspection            06A
# 5       Pre-permit (Operational) / Initial Inspection            10F
# ...                                               ...            ...
# 397075          Cycle Inspection / Initial Inspection            10B
# 397076          Cycle Inspection / Initial Inspection            08B
# 397077               Cycle Inspection / Re-inspection            02H
# 397078          Cycle Inspection / Initial Inspection            04E
# 397079       Pre-permit (Operational) / Re-inspection            04A
#
#                                     VIOLATION DESCRIPTION
# 0       Cold food item held above 41º F (smoked fish a...
# 1       Facility not vermin proof. Harborage or condit...
# 2              Hot food item not held at or above 140º F.
# 3       Personal cleanliness inadequate. Outer garment...
# 5       Non-food contact surface improperly constructe...
# ...                                                   ...
# 397075  Plumbing not properly installed or maintained;...
# 397076  Covered garbage receptacle not provided or ina...
# 397077  Food not cooled by an approved method whereby ...
# 397078  Toxic chemical improperly labeled, stored or u...
# 397079  Food Protection Certificate not held by superv...
#
# [382203 rows x 13 columns]

# %%
rds_connection_string = "postgres:Dontwana1992@localhost:5432/job_posting_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
Clean_Restaurant_Inspection_Results_df .to_sql(name='restaurant_inspections',con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from restaurant_inspections', con=engine).head()
# Out:
#         CAMIS                           DBA       BORO BUILDING  \
# 0  41232877.0                     GEO SI GI     Queens    15228
# 1  50014465.0  MIYABI SUSHI & ASIAN CUISINE  Manhattan      118
# 2  50056033.0        LA COLOMBIANITA BAKERY     Queens    10837
# 3  41081943.0                        SUBWAY  Manhattan        1
# 4  41628216.0                   OVI'S PLACE   Brooklyn     2925
#
#                STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  NORTHERN BOULEVARD  11354.0  7188880001              Korean
# 1            W 3RD ST  10012.0  2122281688            Japanese
# 2          CORONA AVE  11368.0  7183930063              Bakery
# 3          PENN PLAZA  10119.0  2122394212          Sandwiches
# 4            AVENUE H  11210.0  7184211640            American
#
#   INSPECTION DATE                                           ACTION  \
# 0      02/13/2018  Violations were cited in the following area(s).
# 1      12/08/2017  Violations were cited in the following area(s).
# 2      05/23/2017  Violations were cited in the following area(s).
# 3      05/07/2018  Violations were cited in the following area(s).
# 4      07/29/2019  Violations were cited in the following area(s).
#
#   RECORD DATE                                    INSPECTION TYPE  \
# 0  11/18/2019                   Cycle Inspection / Re-inspection
# 1  11/18/2019                   Cycle Inspection / Re-inspection
# 2  11/18/2019              Cycle Inspection / Initial Inspection
# 3  11/18/2019              Cycle Inspection / Initial Inspection
# 4  11/18/2019  Administrative Miscellaneous / Initial Inspection
#
#   VIOLATION CODE                              VIOLATION DESCRIPTION
# 0            02G  Cold food item held above 41º F (smoked fish a...
# 1            08A  Facility not vermin proof. Harborage or condit...
# 2            02B         Hot food item not held at or above 140º F.
# 3            06A  Personal cleanliness inadequate. Outer garment...
# 4            22G                                               None

# %%
Clean_Restaurant_Inspection_Results_df['INSPECTION DATETIME'] = pd.to_datetime(Clean_Restaurant_Inspection_Results_df['INSPECTION DATE'])

# %%
Clean_Restaurant_Inspection_Results_df['INSPECTION YEAR'] = Clean_Restaurant_Inspection_Results_df['INSPECTION DATETIME'].dt.year

# %%
Clean_Restaurant_Inspection_Results_df.head()
# Out:
#                             DBA       BORO BUILDING              STREET  \
# 0                     GEO SI GI     Queens    15228  NORTHERN BOULEVARD
# 1  MIYABI SUSHI & ASIAN CUISINE  Manhattan      118            W 3RD ST
# 2        LA COLOMBIANITA BAKERY     Queens    10837          CORONA AVE
# 3                        SUBWAY  Manhattan        1          PENN PLAZA
# 4                   OVI'S PLACE   Brooklyn     2925            AVENUE H
#
#    ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  11354.0  7188880001              Korean      02/13/2018
# 1  10012.0  2122281688            Japanese      12/08/2017
# 2  11368.0  7183930063              Bakery      05/23/2017
# 3  10119.0  2122394212          Sandwiches      05/07/2018
# 4  11210.0  7184211640            American      07/29/2019
#
#                                             ACTION RECORD DATE  \
# 0  Violations were cited in the following area(s).  11/18/2019
# 1  Violations were cited in the following area(s).  11/18/2019
# 2  Violations were cited in the following area(s).  11/18/2019
# 3  Violations were cited in the following area(s).  11/18/2019
# 4  Violations were cited in the following area(s).  11/18/2019
#
#                                      INSPECTION TYPE VIOLATION CODE  \
# 0                   Cycle Inspection / Re-inspection            02G
# 1                   Cycle Inspection / Re-inspection            08A
# 2              Cycle Inspection / Initial Inspection            02B
# 3              Cycle Inspection / Initial Inspection            06A
# 4  Administrative Miscellaneous / Initial Inspection            22G
#
#                                VIOLATION DESCRIPTION INSPECTION DATETIME  \
# 0  Cold food item held above 41º F (smoked fish a...          2018-02-13
# 1  Facility not vermin proof. Harborage or condit...          2017-12-08
# 2         Hot food item not held at or above 140º F.          2017-05-23
# 3  Personal cleanliness inadequate. Outer garment...          2018-05-07
# 4                                                NaN          2019-07-29
#
#    INSPECTION YEAR
# 0             2018
# 1             2017
# 2             2017
# 3             2018
# 4             2019

# %%
Clean_Restaurant_Inspection_Results_df.to_csv(('./Resources/NYC_Restaurant_Inspection.csv'))
